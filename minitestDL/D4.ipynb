# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("weatherAUS.csv")

# %%
data.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df = data.copy()

# %%
sns.displot(df['MinTemp'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['MinTemp'].fillna(df['MinTemp'].mean(),inplace=True)

# %%
sns.displot(df['MaxTemp'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['MaxTemp'].fillna(df['MaxTemp'].median(),inplace=True)

# %%
sns.displot(df['Rainfall'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Rainfall
df['MaxTemp'].fillna(df['MaxTemp'].median(),inplace=True)

# %%
#Evaporation
sns.displot(df['Evaporation'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Evaporation'].fillna(df['Evaporation'].median(),inplace=True)

# %%
#Sunshine
sns.displot(df['Sunshine'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Sunshine'].fillna(df['Sunshine'].median(),inplace=True)

# %%
#WindGustSpeed
sns.displot(df['WindGustSpeed'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['WindGustSpeed'].fillna(df['WindGustSpeed'].mean(),inplace=True)

# %%
sns.displot(df['WindSpeed9am'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['WindSpeed9am'].fillna(df['WindSpeed9am'].median(),inplace=True)

# %%
sns.displot(df['WindSpeed3pm'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['WindSpeed3pm'].fillna(df['WindSpeed3pm'].median(),inplace=True)

# %%
sns.displot(df['Humidity9am'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Humidity9am'].fillna(df['Humidity9am'].median(),inplace=True)

# %%
sns.displot(df['Humidity3pm'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Humidity3pm'].fillna(df['Humidity3pm'].mean(),inplace=True)

# %%
sns.displot(df['Pressure9am'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Pressure9am'].fillna(df['Pressure9am'].median(),inplace=True)

# %%
sns.displot(df['Pressure9am'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Pressure9am'].fillna(df['Pressure9am'].median(),inplace=True)

# %%
df['Pressure9am'].skew()
# Out:
# -0.0985839658636842

# %%
#Pressure3pm
sns.displot(df['Pressure3pm'], kind="kde")
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['Pressure3pm'].fillna(df['Pressure3pm'].median(),inplace=True)

# %%
df['Cloud9am'].skew()
# Out:
# -0.229081832248417

# %%
df['Cloud3pm'].skew()
# Out:
# -0.22638434607149094

# %%
df['Cloud9am'].fillna(df['Cloud9am'].mean(),inplace=True)
df['Cloud3pm'].fillna(df['Cloud3pm'].mean(),inplace=True)

# %%
df['Temp9am'].skew()
# Out:
# 0.08853999659506906

# %%
df['Temp3pm'].skew()
# Out:
# 0.2379603639909972

# %%
df['Temp9am'].fillna(df['Temp9am'].mean(),inplace=True)
df['Temp3pm'].fillna(df['Temp3pm'].mean(),inplace=True)

# %%
df['Rainfall'].fillna(0,inplace=True)

# %%
df['WindGustDir'].fillna('w',inplace=True)

# %%
df['WindDir9am'].fillna(df['WindDir9am'].mode,inplace=True)

# %%
df['WindDir3pm'].fillna(df['WindDir3pm'].mode,inplace=True)

# %%
df.isna().sum()
# Out:
# Date                0
# Location            0
# MinTemp             0
# MaxTemp             0
# Rainfall            0
# Evaporation         0
# Sunshine            0
# WindGustDir         0
# WindGustSpeed       0
# WindDir9am          0
# WindDir3pm          0
# WindSpeed9am        0
# WindSpeed3pm        0
# Humidity9am         0
# Humidity3pm         0
# Pressure9am         0
# Pressure3pm         0
# Cloud9am            0
# Cloud3pm            0
# Temp9am             0
# Temp3pm             0
# RainToday        3261
# RainTomorrow     3267
# dtype: int64

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# Date             0
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# RainTomorrow     0
# dtype: int64

# %%
dummies = pd.get_dummies(df['Location'])
df_onehot = pd.concat([df,dummies], axis = 1)
df_onehot.drop("Location",axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
#for name in data.columns:
df_onehot['WindGustDir'] = le.fit_transform(df_onehot['WindGustDir'])
print(df_onehot['WindGustDir'])
# Out:
# 0         13
# 1         14
# 2         15
# 3          4
# 4         13
#           ..
# 145454     0
# 145455     0
# 145456     6
# 145457     3
# 145458     9
# Name: WindGustDir, Length: 140787, dtype: int32

# %%
df_onehot['WindDir9am'] = df_onehot['WindDir9am'].astype(str)
df_onehot['WindDir9am'] = le.fit_transform(df_onehot['WindDir9am'])

# %%
df_onehot.drop("Date",axis=1,inplace=True)

# %%
df_onehot['RainToday'] = le.fit_transform(df_onehot['RainToday'])

# %%
df_onehot['RainTomorrow'] = le.fit_transform(df_onehot['RainTomorrow'])

# %%
df_onehot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 140787 entries, 0 to 145458
# Data columns (total 70 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   MinTemp           140787 non-null  float64
#  1   MaxTemp           140787 non-null  float64
#  2   Rainfall          140787 non-null  float64
#  3   Evaporation       140787 non-null  float64
#  4   Sunshine          140787 non-null  float64
#  5   WindGustDir       140787 non-null  int32
#  6   WindGustSpeed     140787 non-null  float64
#  7   WindDir9am        140787 non-null  int32
#  8   WindDir3pm        140787 non-null  int32
#  9   WindSpeed9am      140787 non-null  float64
#  10  WindSpeed3pm      140787 non-null  float64
#  11  Humidity9am       140787 non-null  float64
#  12  Humidity3pm       140787 non-null  float64
#  13  Pressure9am       140787 non-null  float64
#  14  Pressure3pm       140787 non-null  float64
# ...

# %%
from sklearn.model_selection import train_test_split
X = df_onehot.drop(['RainTomorrow'],axis=1)
Y = df_onehot['RainTomorrow']
X_train,X_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
#ANN
import tensorflow as tf
from tensorflow import keras

# %%
X_train.shape
# Out:
# (112629, 69)

# %%
model = keras.models.Sequential()
activation = 'relu'
model.add(keras.layers.Flatten(input_shape=[69]))
model.add(keras.layers.Dense(69,activation=activation))
model.add(keras.layers.Dense(35,activation=activation))
model.add(keras.layers.Dense(1,activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_3 (Flatten)         (None, 69)                0
#
#  dense_9 (Dense)             (None, 69)                4830
#
#  dense_10 (Dense)            (None, 35)                2450
#
#  dense_11 (Dense)            (None, 1)                 36
#
# ...
# Total params: 7316 (28.58 KB)
# Trainable params: 7316 (28.58 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss="BinaryCrossentropy",optimizer="adam",metrics=["accuracy"])

# %%
X_train
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 127115      7.1     14.6       7.8          4.8       8.4           12
# 72954       7.6     26.4       0.0          3.6      10.8            2
# 52102       2.0     17.0       0.0          4.8       8.4           16
# 126848     17.2     23.8       0.0          4.8       8.4           10
# 26837       7.8     20.2       0.0          4.8       8.4           14
# ...         ...      ...       ...          ...       ...          ...
# 109235     11.8     18.0       0.0          3.8       3.3           16
# 65764       3.9      9.9       6.6          1.4       8.4            3
# 106290     23.2     42.0       0.0         16.0       8.4            5
# 5297        3.6     15.1       2.0          4.8       8.4           15
# 99678      12.5     16.8       3.6          1.4       0.5           14
#
#         WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Townsville  \
# ...

# %%
history = model.fit(X_train,y_train,validation_data = (X_test,y_test),epochs = 30)
# Out:
# Epoch 1/30
# 3520/3520 [==============================] - 22s 5ms/step - loss: 0.7121 - accuracy: 0.8010 - val_loss: 0.3987 - val_accuracy: 0.8420
# Epoch 2/30
# 3520/3520 [==============================] - 19s 5ms/step - loss: 0.4575 - accuracy: 0.8149 - val_loss: 0.5338 - val_accuracy: 0.7504
# Epoch 3/30
# 3520/3520 [==============================] - 19s 5ms/step - loss: 0.4273 - accuracy: 0.8217 - val_loss: 0.3736 - val_accuracy: 0.8373
# Epoch 4/30
# 3520/3520 [==============================] - 19s 5ms/step - loss: 0.4063 - accuracy: 0.8283 - val_loss: 0.3679 - val_accuracy: 0.8408
# Epoch 5/30
# 3520/3520 [==============================] - 19s 5ms/step - loss: 0.3851 - accuracy: 0.8357 - val_loss: 0.3719 - val_accuracy: 0.8389
# Epoch 6/30
# 3520/3520 [==============================] - 20s 6ms/step - loss: 0.3760 - accuracy: 0.8389 - val_loss: 0.3641 - val_accuracy: 0.8461
# Epoch 7/30
# ...

# %%
plt.plot(history.history["accuracy"],c='b')
plt.plot(history.history["val_accuracy"],c='r')
plt.grid()
plt.legend(["Training Acc","Validation Acc"])

import sklearn.metrics as metrics
y_pred = model.predict(X_test)
#print(y_pred)
y_pred = [1 if i > 0.5 else 0 for i in y_pred]

acc = metrics.accuracy_score(y_test,y_pred)
precision = metrics.precision_score(y_test,y_pred)
recall = metrics.recall_score(y_test,y_pred)

print(f'accuracy : {acc}')
print(f'precision : {precision}')
print(f'recall : {recall}')
# Out:
# 880/880 [==============================] - 3s 3ms/step
# accuracy : 0.8496342069749272
# precision : 0.7092059336823735
# recall : 0.528446033810143
